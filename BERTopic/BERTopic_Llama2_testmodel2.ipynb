# %% [markdown]
# # **Version 2**
#
#
# **Improvements / Changes**
# * Reorder code ✔
# * Place all installs in one cell ✔
# * Place all libraries in one cell ✔
# *   Adjust prompt, ask for multiple representative jobs per topic instead of one label ✔
# *   Improve topic modeling with BERTopic by adjusting parameters ✔
# * Use larger part of the dataset ✔
# * Test larger job description by increasing Max words ✔
# * Test with preprocessed_historical_data.csv ✔
# * IMPORTANT, use: reduce_outliers(look into with gpt), reduce_topics(), update_topis(representation_model, top_n_words, n_gram_range, vectorizer_model)

# %% [markdown]
# 1. Reduce outliers with strategy=embeddings, distributions, probabilities, threshold=0.5?, SET calculate_probabilities=True when initializing BERTopic!, embeddings must be precomputed.
# 2. Reduce topics with reduce_topics() to around 35-70 topics
# 3. Update topics based on representation model, top n words and n gram range.

# %%
# %%capture
# !pip install transformers bertopic accelerate bitsandbytes xformers adjustText datamapplot umap-learn optuna gensim

# %%
from google.colab import drive

import pandas as pd

from huggingface_hub import notebook_login

from torch import cuda
from torch import bfloat16

import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer
from sentence_transformers import SentenceTransformer
from transformers import pipeline

from umap import UMAP
from hdbscan import HDBSCAN

from bertopic import BERTopic
from bertopic.representation import TextGeneration

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import ParameterGrid

import datamapplot
import numpy as np
import matplotlib.pyplot as plt

import optuna
from gensim.models.coherencemodel import CoherenceModel
import gensim.corpora as corpora
from gensim.corpora import Dictionary

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = pd.read_csv('/content/drive/My Drive/Colab Notebooks/preprocessed_historical_data 4.csv')
dataset = dataset.sample(frac=0.25, random_state=42)

dataset
# Out:
#             job_id                             company_name  \
# 73989   3902944011                            Current Power
# 59308   3901960222                             DISH Network
# 44663   3900944095  Coca-Cola Bottling Company UNITED, Inc.
# 81954   3903878594                        Denver7 (KMGH-TV)
# 113151  3905670593                  BAYADA Home Health Care
# ...            ...                                      ...
# 118068  3906088336           Activ8 Recruitment & Solutions
# 96827   3904951786                    Take2 Consulting, LLC
# 80628   3903843265                                   Podium
# 8368    3886202733                                    Jobot
# 34997   3895521938                                 ZoomInfo
#
#                                                     title  \
# 73989          Senior Automation Engineer - Power Systems
# 59308                DISH Installation Technician - Field
# 44663                                       Order Builder
# 81954                Mountain Multimedia Journalist, KMGH
# 113151                     Licensed Practical Nurse (LPN)
# ...                                                   ...
# 118068  Sales Representative - Resin / Polymer Materia...
# 96827                               Director Sales Market
# 80628                     Sales Operations Analyst (2024)
# 8368                                    Attorney (MedMal)
# 34997                       Director, Customer Onboarding
#
#                                               description       location  \
# 73989   The Senior Automation / Power Systems Engineer...    Houston, TX
# 59308   Company Summary\n\nDISH, an EchoStar Company, ...     Orange, TX
# 44663   Division: North Alabama\n\nDepartment : Oxford...     Oxford, AL
# 81954   KMGH, the E.W. Scripps Company ABC affiliate i...     Denver, CO
# 113151  Come for the Flexibility, Stay for the Culture...  Teterboro, NJ
# ...                                                   ...            ...
# 118068  An international chemical manufacturing compan...       Novi, MI
# 96827   Are you prepared to excel as a Market Director...     Vienna, VA
# 80628   At Podium, our mission is to help local busine...       Lehi, UT
# 8368    Want to learn more about this role and Jobot? ...    Ontario, CA
# 34997   At ZoomInfo, we encourage creativity, value in...  Vancouver, WA
#
#        formatted_work_type original_listed_time               expiry  \
# 73989            Full-time  2024-04-16 15:01:21  2024-05-16 15:01:21
# 59308            Full-time  2024-04-18 21:49:34  2024-05-18 22:02:03
# 44663            Full-time  2024-04-17 21:06:28  2024-05-17 21:18:20
# 81954            Full-time  2024-04-19 03:01:37  2024-05-19 03:12:28
# 113151           Full-time  2024-04-18 00:00:00  2024-05-19 09:55:42
# ...                    ...                  ...                  ...
# 118068           Full-time  2024-04-19 18:32:38  2024-05-19 18:32:38
# 96827            Full-time  2024-04-18 15:33:33  2024-05-18 15:33:32
# 80628            Part-time  2024-04-18 00:00:00  2024-05-18 22:55:23
# 8368             Full-time  2024-04-06 09:47:53  2024-05-06 10:13:45
# 34997            Full-time  2024-04-11 00:00:00  2024-05-12 02:22:37
#
#                                           job_posting_url  \
# 73989   https://www.linkedin.com/jobs/view/3902944011/...
# 59308   https://www.linkedin.com/jobs/view/3901960222/...
# 44663   https://www.linkedin.com/jobs/view/3900944095/...
# 81954   https://www.linkedin.com/jobs/view/3903878594/...
# 113151  https://www.linkedin.com/jobs/view/3905670593/...
# ...                                                   ...
# 118068  https://www.linkedin.com/jobs/view/3906088336/...
# 96827   https://www.linkedin.com/jobs/view/3904951786/...
# 80628   https://www.linkedin.com/jobs/view/3903843265/...
# 8368    https://www.linkedin.com/jobs/view/3886202733/...
# 34997   https://www.linkedin.com/jobs/view/3895521938/...
#
#        formatted_experience_level  \
# 73989            Mid-Senior level
# 59308               Not Specified
# 44663                 Entry level
# 81954                 Entry level
# 113151                Entry level
# ...                           ...
# 118068                  Associate
# 96827                    Director
# 80628            Mid-Senior level
# 8368             Mid-Senior level
# 34997                    Director
#
#                                       cleaned_description  \
# 73989   senior automation power system engineer primar...
# 59308   company summary dish echostar company reimagin...
# 44663   division north alabama department oxford wareh...
# 81954   kmgh scripps company abc affiliate denver colo...
# 113151  come flexibility stay culture needing life bal...
# ...                                                   ...
# 118068  international chemical manufacturing company n...
# 96827   prepared excel market director innovative rapi...
# 80628   podium mission help local business win lead co...
# 8368    want learn role jobot click jobot logo follow ...
# 34997   zoominfo encourage creativity value innovation...
#
#                                             cleaned_title
# 73989             senior automation engineer power system
# 59308                  dish installation technician field
# 44663                                       order builder
# 81954                 mountain multimedia journalist kmgh
# 113151                       licensed practical nurse lpn
# ...                                                   ...
# 118068  sale representative resin polymer material hyb...
# 96827                                director sale market
# 80628                         sale operation analyst 2024
# 8368                                      attorney medmal
# 34997                        director customer onboarding
#
# [30962 rows x 12 columns]

# %%
# Fill missing values in the "description" column with an empty string
dataset["cleaned_description"] = dataset["cleaned_description"].fillna("")

# Ensure all values are strings
dataset["cleaned_description"] = dataset["cleaned_description"].astype(str)

# Limit the number of words in the description column so the model can handle the inputs
MAX_WORDS = 50
dataset["cleaned_description"] = dataset["cleaned_description"].apply(lambda x: ' '.join(x.split()[:MAX_WORDS]))

# Combine titles and descriptions into a single column
dataset["combined"] = dataset["cleaned_title"] + " " + dataset["cleaned_description"]

titles = dataset["cleaned_title"]
description = dataset["cleaned_description"]
combined = dataset["combined"].astype(str)
combined = combined.reset_index(drop=True)

# Check combined variable
print(f"Example combined entry: {dataset['combined'].iloc[0]}")
# Out:
# Example combined entry: senior automation engineer power system senior automation power system engineer primarily responsible conception design development implementation electrical system candidate extensive knowledge electrical power system ac drive technology active front end afe system plc programming experience candidate also posse ability apply mathematical engineering principle detailed description responsible designing developing electrical system including generator control switchboard ac

# %% [markdown]
# # **BERTopic Model**

# %%
# Pre-calculate embeddings
embedding_model = SentenceTransformer("BAAI/bge-large-en")
embeddings = embedding_model.encode(combined, show_progress_bar=True)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/90.3k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/720 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]
# Batches:   0%|          | 0/968 [00:00<?, ?it/s]

# %%
vectorizer_model = CountVectorizer(stop_words="english")

# %%
# def objective(trial):
#     # Suggest hyperparameters
#     min_topic_size = trial.suggest_int("min_topic_size", 50, 100)
#     n_neighbors = trial.suggest_int("n_neighbors", 50, 100)
#     n_components = trial.suggest_int("n_components", 2, 4)
#     min_dist = trial.suggest_float("min_dist", 0.1, 0.3)
#     n_gram_range = trial.suggest_categorical("n_gram_range", [(1, 2), (1, 3), (1, 4)])

#     # Sub-models
#     umap_model = UMAP(
#         n_neighbors=n_neighbors,
#         n_components=n_components,
#         min_dist=min_dist,
#         metric="cosine",
#         random_state=42
#     )
#     hdbscan_model = HDBSCAN(
#         min_cluster_size=20,
#         min_samples=20,
#         metric="euclidean",
#         cluster_selection_method="eom",
#         prediction_data=True
#     )

#     # Initialize BERTopic
#     topic_model = BERTopic(
#         vectorizer_model=vectorizer_model,
#         umap_model=umap_model,
#         # hdbscan_model=hdbscan_model,
#         n_gram_range=n_gram_range,
#         min_topic_size=min_topic_size,
#         verbose=True
#     )

#     # Fit the model
#     topics, _ = topic_model.fit_transform(combined, embeddings)

#     # Count the number of outliers (-1 topics)
#     outlier_count = sum(1 for t in topics if t == -1)
#     outlier_percentage = outlier_count / len(combined)
#     print(f"Trial {trial.number}: Outlier Percentage: {outlier_percentage:.2%}")

#     # Calculate the number of topics (excluding outliers)
#     unique_topics = set(t for t in topics if t != -1)
#     num_topics = len(unique_topics)
#     print(f"Trial {trial.number}: Number of topics: {num_topics}")

#     # Constraints
#     if outlier_percentage > 0.30 or not (200 <= num_topics <= 1000):
#         print(f"Trial {trial.number}: Rejected due to constraints (Outliers/Topics).")
#         return 0  # Penalize heavily if constraints are violated

#     # Filter out topics with ID -1
#     filtered_data = [
#         (doc, topic) for doc, topic in zip(combined, topics) if topic != -1
#     ]
#     if not filtered_data:  # Handle case where all topics are outliers
#         print(f"Trial {trial.number} failed: All documents classified as outliers.")
#         return 0

#     filtered_combined, filtered_topics = zip(*filtered_data)

#     # Group documents by topic
#     documents = pd.DataFrame({
#         "Document": filtered_combined,
#         "ID": range(len(filtered_combined)),
#         "Topic": filtered_topics
#     })
#     documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
#     cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

#     # Define vectorizer and analyzer
#     vectorizer = topic_model.vectorizer_model
#     analyzer = vectorizer.build_analyzer()

#     # Create tokens, dictionary, and corpus
#     words = vectorizer.get_feature_names_out()
#     tokens = [analyzer(doc) for doc in cleaned_docs]
#     dictionary = corpora.Dictionary(tokens)
#     corpus = [dictionary.doc2bow(token) for token in tokens]

#     # Extract topic words
#     topic_words = [[word for word, _ in topic_model.get_topic(topic)]
#                    for topic in range(len(set(filtered_topics)))]

#     # Compute coherence score
#     coherence_model = CoherenceModel(
#         topics=topic_words,
#         texts=tokens,
#         dictionary=dictionary,
#         coherence='c_v'
#     )
#     coherence_score = coherence_model.get_coherence()

#     # Add penalties to the coherence score
#     penalty = 0
#     if outlier_percentage > 0.40:  # Add penalty for outliers between 25%-30%
#         penalty -= (outlier_percentage - 0.40) * 10  # Adjust penalty weight as needed
#     if num_topics < 35:  # Add penalty for fewer topics
#         penalty -= (35 - num_topics) * 0.5
#     elif num_topics > 100:  # Add penalty for excess topics
#         penalty -= (num_topics - 100) * 0.5

#     final_score = coherence_score + penalty
#     print(f"Trial {trial.number}: Coherence Score: {coherence_score}, Final Score: {final_score}")

#     return final_score

# %%
# # Optimize hyperparameters using Optuna
# study = optuna.create_study(direction="maximize")
# study.optimize(objective, n_trials=10)

# # Best hyperparameters
# best_params = study.best_params
# print("Best hyperparameters:", best_params)
# print("Best coherence score:", study.best_value)

# %%
# df = study.trials_dataframe()
# df
# Out:
#    number     value             datetime_start          datetime_complete  \
# 0       0  0.784551 2024-12-16 15:32:56.006404 2024-12-16 15:34:32.093599
# 1       1  0.833971 2024-12-16 15:34:32.095618 2024-12-16 15:35:53.682678
# 2       2  0.803960 2024-12-16 15:35:53.688213 2024-12-16 15:37:15.176044
# 3       3  0.729255 2024-12-16 15:37:15.179735 2024-12-16 15:38:23.819442
# 4       4  0.779651 2024-12-16 15:38:23.822740 2024-12-16 15:39:56.783837
#
#                 duration  params_min_dist  params_min_topic_size  \
# 0 0 days 00:01:36.087195         0.208005                     48
# 1 0 days 00:01:21.587060         0.218563                     42
# 2 0 days 00:01:21.487831         0.202496                     55
# 3 0 days 00:01:08.639707         0.489785                     71
# 4 0 days 00:01:32.961097         0.349150                     53
#
#    params_n_components params_n_gram_range  params_n_neighbors     state
# 0                    4              (1, 2)                  42  COMPLETE
# 1                    5              (1, 4)                  43  COMPLETE
# 2                    3              (1, 3)                  50  COMPLETE
# 3                    2              (1, 3)                  43  COMPLETE
# 4                    4              (1, 4)                  61  COMPLETE

# %%
# Test without labeling topics
#{'min_topic_size': 79, 'n_neighbors': 59, 'n_components': 2, 'min_dist': 0.2575987952763153, 'n_gram_range': (1, 4)}

umap_model = UMAP(
    n_neighbors=10,
    n_components=5,
    min_dist=0.1,
    metric='cosine',
    random_state=42)

hdbscan_model = HDBSCAN(min_cluster_size=15,
                        min_samples=None,
                        metric="euclidean",
                        cluster_selection_method="eom",
                        prediction_data=True)

# Training BERTopic model to find best hyperparameters
topic_model = BERTopic(

  # Sub-models
  # vectorizer_model=vectorizer_model,
  umap_model=umap_model,
  hdbscan_model=hdbscan_model,

  # Hyperparameters
  min_topic_size=20,
  n_gram_range=(1,3),
  verbose=True,
  calculate_probabilities=True
)

# Train model
topics, probs = topic_model.fit_transform(combined, embeddings)

# topic_model.save("bertopic_model_all")
# Out:
# 2024-12-23 10:37:10,095 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-12-23 10:38:02,682 - BERTopic - Dimensionality - Completed ✓
# 2024-12-23 10:38:02,685 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-12-23 10:42:26,236 - BERTopic - Cluster - Completed ✓
# 2024-12-23 10:42:26,250 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-12-23 10:42:38,327 - BERTopic - Representation - Completed ✓

# %%
topic_model.get_topic_info().head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8fdd4daf844d> in <cell line: 1>()
# ----> 1 topic_model.get_topic_info().head(20)
#
# NameError: name 'topic_model' is not defined

# %%
topic_model.get_topic(0)
# Out:
# [('project', 0.02756681500625131),
#  ('project manager', 0.02164597991562017),
#  ('manager', 0.010982741335317759),
#  ('construction', 0.010321413063816879),
#  ('program manager', 0.007896146846620006),
#  ('project management', 0.006782478946692517),
#  ('construction project', 0.006224687326564847),
#  ('management', 0.005823530239290635),
#  ('program', 0.005674891334953495),
#  ('senior project', 0.005386164758610527)]

# %%
print(probs.shape)

print(probs)
# Out:
# (30962, 354)
# [[3.48309057e-03 2.27887585e-03 1.16953141e-03 ... 7.46794120e-04
#   1.64207123e-03 1.44243508e-03]
#  [1.03434461e-06 8.90869431e-07 1.06491418e-06 ... 1.13580889e-06
#   9.55146576e-07 9.88876899e-07]
#  [2.32659323e-03 1.39516555e-03 1.63139334e-03 ... 6.36427211e-04
#   1.98747695e-03 1.93386897e-03]
#  ...
#  [2.90014481e-03 1.74855202e-03 1.38928014e-03 ... 5.28323763e-04
#   2.09861143e-03 2.27364015e-03]
#  [2.07543626e-03 1.64657272e-03 8.73712748e-04 ... 4.75486501e-04
#   1.38170647e-03 1.08688621e-03]
#  [4.77497986e-03 2.84418311e-03 2.12115949e-03 ... 8.22083721e-04
#   3.19463997e-03 3.09576836e-03]]

# %%
def compute_coherence_score(topic_model, combined, topics, coherence_type='c_v'):
    """
    Computes the coherence score for a BERTopic model.

    Parameters:
    - topic_model: BERTopic
        The trained BERTopic model.
    - combined: List[str]
        The list of input documents used in training the model.
    - topics: List[int]
        The topic assignments for the documents.
    - coherence_type: str
        The type of coherence metric to use. Default is 'c_v'.

    Returns:
    - float
        The computed coherence score.
    """
    # Group documents by topic
    documents = pd.DataFrame({"Document": combined, "ID": range(len(combined)), "Topic": topics})
    documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
    cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

    # Extract vectorizer and analyzer
    vectorizer = topic_model.vectorizer_model
    analyzer = vectorizer.build_analyzer()

    # Create tokens, dictionary, and corpus
    tokens = [analyzer(doc) for doc in cleaned_docs]
    dictionary = Dictionary(tokens)
    corpus = [dictionary.doc2bow(token) for token in tokens]

    # Extract topic words
    topic_words = [
        [word for word, _ in topic_model.get_topic(topic)]
        for topic in range(len(set(topics)) - 1)
    ]

    # Compute coherence

    coherence_model = CoherenceModel(
        topics=topic_words,
        texts=tokens,
        corpus=corpus,
        dictionary=dictionary,
        coherence=coherence_type
    )
    coherence = coherence_model.get_coherence()

    print(f"Coherence Score ({coherence_type}): {coherence}")
    return coherence

# %%
score = compute_coherence_score(topic_model, combined, topics, coherence_type='c_v')
# Out:
# Coherence Score (c_v): 0.3290952383540109

# %%
# Reduce outliers from the model
reduced_outliers = topic_model.reduce_outliers(
    documents=combined,
    topics=topics,
    strategy='probabilities',
    probabilities=probs,
    # threshold=0.05
    # embeddings=embeddings
    )

# %%
topic_model.update_topics(docs=combined, topics=reduced_outliers)
# Out:
# 2024-12-21 12:54:18,613 - BERTopic - WARNING: Using a custom list of topic assignments may lead to errors if topic reduction techniques are used afterwards. Make sure that manually assigning topics is the last step in the pipeline.Note that topic embeddings will also be created through weightedc-TF-IDF embeddings instead of centroid embeddings.

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                               Name  \
# 0        0    655     0_project_project manager_manager_construction
# 1        1    481             1_developer_java_salesforce_experience
# 2        2    359                    2_attorney_litigation_legal_law
# 3        3    327  3_accountant_accounting_senior accountant_staf...
# 4        4    404           4_analyst_business analyst_business_data
# ..     ...    ...                                                ...
# 349    349     70                        349_invited_accor_club_golf
# 350    350     50  350_datavant_health_healthcare_data logistics ...
# 351    351     39               351_rv_verizon_camping world_camping
# 352    352    128                       352_finance_loan_credit_fund
# 353    353     47                         353_bmo_bank_branch_banker
#
#                                         Representation  \
# 0    [project, project manager, manager, constructi...
# 1    [developer, java, salesforce, experience, stac...
# 2    [attorney, litigation, legal, law, paralegal, ...
# 3    [accountant, accounting, senior accountant, st...
# 4    [analyst, business analyst, business, data, sy...
# ..                                                 ...
# 349  [invited, accor, club, golf, chicken, restaura...
# 350  [datavant, health, healthcare, data logistics ...
# 351  [rv, verizon, camping world, camping, world, c...
# 352  [finance, loan, credit, fund, treasury, invest...
# 353  [bmo, bank, branch, banker, bmo partner, relat...
#
#                                    Representative_Docs
# 0    [project manager construction project manager ...
# 1    [full stack java developer role senior full st...
# 2    [litigation paralegal personal injury morgan m...
# 3    [senior accountant senior accountant remote su...
# 4    [salesforce business analyst salesforce busine...
# ..                                                 ...
# 349  [barista job description invited invited club ...
# 350  [patient care technician urgent care led organ...
# 351  [technical project manager join verizon verizo...
# 352  [financial system manager req number r2356 emp...
# 353  [associate banker central park bilingual prefe...
#
# [354 rows x 5 columns]

# %%
topic_model.get_topic(0)
# Out:
# [('engineer', 0.01209009988726746),
#  ('data', 0.010337793508504617),
#  ('software', 0.009982906746637953),
#  ('developer', 0.008591113541535828),
#  ('experience', 0.008424262590094714),
#  ('security', 0.007412362108307108),
#  ('system', 0.007276760180496747),
#  ('cloud', 0.007186922773749228),
#  ('technology', 0.006824827479783184),
#  ('solution', 0.006401470471145965)]

# %%
reduced_outlier_score = compute_coherence_score(topic_model, combined, reduced_outliers, coherence_type='c_v')
# Out:
# Coherence Score (c_v): 0.3678589822943739

# %%
topic_model.reduce_topics(docs=combined, nr_topics=100)
# Out:
# 2024-12-21 12:59:48,000 - BERTopic - Topic reduction - Reducing number of topics
# 2024-12-21 13:00:00,803 - BERTopic - Topic reduction - Reduced number of topics from 354 to 100

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0       0  10744                       0_manager_team_sale_customer
# 1       1   4271                    1_maintenance_team_work_service
# 2       2   2732                   2_product_team_manager_warehouse
# 3       3   1961                  3_financial_marketing_team_client
# 4       4   1443                    4_patient_customer_service_care
# ..    ...    ...                                                ...
# 95     95     18          95_chatbots_ai_train ai_train ai chatbots
# 96     96     16  96_route service_route_service sale representa...
# 97     97     16  97_mohawk_mohawk industry_productive life outs...
# 98     98     16  98_horton_mortgage_mortgage title_mortgage fin...
# 99     99     16                    99_pet_petco_future pet_welcome
#
#                                        Representation  \
# 0   [manager, team, sale, customer, job, service, ...
# 1   [maintenance, team, work, service, support, po...
# 2   [product, team, manager, warehouse, position, ...
# 3   [financial, marketing, team, client, job, serv...
# 4   [patient, customer, service, care, sap, custom...
# ..                                                ...
# 95  [chatbots, ai, train ai, train ai chatbots, ai...
# 96  [route service, route, service sale representa...
# 97  [mohawk, mohawk industry, productive life outs...
# 98  [horton, mortgage, mortgage title, mortgage fi...
# 99  [pet, petco, future pet, welcome, improve, fut...
#
#                                   Representative_Docs
# 0   [team member store 2746236 1543 lake street fo...
# 1   [sale manager position summary sale manager ma...
# 2   [behavior technician looking enthusiastic indi...
# 3   [mgr case management made lot progress since o...
# 4   [sale specialist position white cap ordinary j...
# ..                                                ...
# 95  [web developer dataannotation committed creati...
# 96  [route service sale representative workweek re...
# 97  [material handler join largest manufacturer ti...
# 98  [loan processor description horton largest hom...
# 99  [veterinary assistant create healthier brighte...
#
# [100 rows x 5 columns]

# %%
# Get the updated topic assignments after reducing topics
updated_topics = topic_model.get_document_info(combined)['Topic']

# Compute coherence score
reduced_coherence_score = compute_coherence_score(
    topic_model=topic_model,
    combined=combined,
    topics=updated_topics,
    coherence_type='c_v'  # You can also use 'u_mass', 'c_uci', etc.
)
# Out:
# Coherence Score (c_v): 0.3889349519329845

# %% [markdown]
# # **LLama2 Model**

# %% [markdown]
# Huggingface token:

# %%
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
device = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'

print(device)
# Out:
# cuda:0

# %%
# Set quantization configuration for loading large models with less GPU memory
bnb_config = transformers.BitsAndBytesConfig(
    load_in_4bit=True,             # Enable 4-bit quantization
    bnb_4bit_quant_type="nf4",     # Use normalized float 4-bit precision
    bnb_4bit_use_double_quant=True,  # Second quantization after the first
    bnb_4bit_compute_dtype=bfloat16  # Compute type for better performance
)

# %%
# Model name for topic label generating
model_id = "meta-llama/Llama-2-7b-chat-hf"

# %%
# Llama 2 Tokenizer
tokenizer = transformers.AutoTokenizer.from_pretrained(model_id, use_auth_token=True)

# Llama 2 Model
model = transformers.AutoModelForCausalLM.from_pretrained(
    model_id,
    trust_remote_code=True,
    quantization_config=bnb_config,
    device_map='auto',
)
model.eval()
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(32000, 4096)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaSdpaAttention(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear4bit(in_features=4096, out_features=11008, bias=False)
#           (up_proj): Linear4bit(in_features=4096, out_features=11008, bias=False)
#           (down_proj): Linear4bit(in_features=11008, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((4096,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
# )

# %%
# Our text generator
generator = pipeline(
    model=model, tokenizer=tokenizer,
    task='text-generation',
    temperature=0.1,
    max_new_tokens=500,
    repetition_penalty=1.1
)
# Out:
# Device set to use cuda:0

# %%
prompt = "Could you explain to me how 4-bit quantization works as if I am 5?"
res = generator(prompt)
print(res[0]["generated_text"])
# Out:
# Could you explain to me how 4-bit quantization works as if I am 5?
#  nobody likes a know-it-all, but I'm here to help! 😊
#
# Quantization is like taking a big box of crayons and sorting them into smaller boxes. Imagine you have a big box of crayons with lots of different colors. You want to give some of these crayons to your little brother or sister, but you don't want to give them all the same color. So, you take the crayons and sort them into smaller boxes based on their colors. This way, you can easily find the right crayon for your little brother or sister when they want to draw something.
#
# In the same way, when we quantize a number, we are taking a big number and breaking it down into smaller parts called bits. Each bit represents a small part of the original number. For example, if we have the number 10, we could break it down into two bits: 01. Now, each bit represents half of the original number. If we want to represent the number 10 again, we can put the two bits together: 01 = 2.
#
# So, just like sorting crayons into smaller boxes helps us find the right one quickly, quantization helps our computer find the right number quickly by breaking it down into smaller parts. And that's why it's important to know how many bits we need to use to represent a particular number accurately! 😃

# %%
# System prompt describes information given to all conversations
system_prompt = """
<s>[INST] <<SYS>>
You are a helpful, respectful, and honest assistant for labeling topics.
<</SYS>>
"""

# Example prompt demonstrating the output we are looking for
example_prompt = """
I have a topic that contains the following documents:
- Developers work on cloud systems and deploy applications for companies using Java, Azure, and AWS.
- Cloud engineers build solutions using Azure and AWS for scalable software platforms.
- Veterinary software developers focus on applications for managing veterinary clinics and pet records.

The topic is described by the following keywords: 'developer, experience, cloud, java, veterinary, application, azure, year, beauty, aws'.

Based on the information about the topic above, please create a short label of this topic. Make sure you only return the label and nothing more.

[/INST] Cloud Software Development
"""

# Main prompt for labeling topics
main_prompt = """
[INST]
I have a topic described by the following keywords: '[KEYWORDS]'.

Based on these keywords, create a concise 1-5 word label for this topic.
Do not consider the content of any documents or specific company names.
Focus only on the most relevant and frequent terms from the keywords.

Ensure you only return the label and nothing more.
[/INST]
"""

# Combine the system, example, and main prompts into one
prompt = system_prompt + example_prompt + main_prompt

# %%
# Text generation with Llama 2
llama2 = TextGeneration(generator, prompt=prompt)

# Representation model
representation_model = {
    "Llama2": llama2,
}

# %%
topic_model.update_topics(docs=combined, representation_model=representation_model)
# Out:
#   3%|▎         | 10/355 [00:04<02:01,  2.83it/s]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 100%|██████████| 355/355 [02:09<00:00,  2.75it/s]

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                               Name  \
# 0       -1  13944                       -1_team_company_work_service
# 1        0    394     0_project_project manager_manager_construction
# 2        1    357                  1_developer_java_salesforce_stack
# 3        2    352                    2_attorney_litigation_legal_law
# 4        3    264  3_accountant_accounting_senior accountant_staf...
# ..     ...    ...                                                ...
# 350    349     15          349_invited_cracker barrel_barrel_cracker
# 351    350     15  350_aid healthcare_aid healthcare foundation_h...
# 352    351     15  351_verizon_connect around world_crisis celebr...
# 353    352     15  352_financial system_finance_finance manager_f...
# 354    353     15       353_bmo_bmo partner_service bmo_bmo customer
#
#                                         Representation  \
# 0    [team, company, work, service, manager, job, p...
# 1    [project, project manager, manager, constructi...
# 2    [developer, java, salesforce, stack, full stac...
# 3    [attorney, litigation, legal, law, paralegal, ...
# 4    [accountant, accounting, senior accountant, st...
# ..                                                 ...
# 350  [invited, cracker barrel, barrel, cracker, clu...
# 351  [aid healthcare, aid healthcare foundation, he...
# 352  [verizon, connect around world, crisis celebra...
# 353  [financial system, finance, finance manager, f...
# 354  [bmo, bmo partner, service bmo, bmo customer, ...
#
#                                        Llama2  \
# 0     [Business Operations, , , , , , , , , ]
# 1      [Project Management, , , , , , , , , ]
# 2          [Full Stack Dev, , , , , , , , , ]
# 3          [Legal Practice, , , , , , , , , ]
# 4              [Accounting, , , , , , , , , ]
# ..                                        ...
# 350   [Inclusive Community, , , , , , , , , ]
# 351        [Healthcare Aid, , , , , , , , , ]
# 352        [Verizon Career, , , , , , , , , ]
# 353  [Financial Management, , , , , , , , , ]
# 354  [BMO Customer Service, , , , , , , , , ]
#
#                                    Representative_Docs
# 0    [building equipment mechanic join verizon veri...
# 1    [project manager construction project manager ...
# 2    [full stack java developer role senior full st...
# 3    [litigation paralegal personal injury morgan m...
# 4    [senior accountant senior accountant remote su...
# ..                                                 ...
# 350  [barista job description invited invited club ...
# 351  [patient care technician urgent care led organ...
# 352  [technical project manager join verizon verizo...
# 353  [financial system manager req number r2356 emp...
# 354  [associate banker central park bilingual prefe...
#
# [355 rows x 6 columns]

# %%
topic_model.get_topic(3)
# Out:
# [('guest', 0.01702203425499397),
#  ('food', 0.016646466314073367),
#  ('restaurant', 0.011715782136144328),
#  ('hotel', 0.011244571627421672),
#  ('service', 0.008139834793662745),
#  ('cook', 0.007350745066419152),
#  ('team', 0.007207085219609822),
#  ('chef', 0.006641397136122993),
#  ('beverage', 0.006639520031835896),
#  ('room', 0.00661672257716577)]

# %% [markdown]
# # **BERTopic with LLama2**

# %%
#{'min_topic_size': 79, 'n_neighbors': 59, 'n_components': 2, 'min_dist': 0.2575987952763153, 'n_gram_range': (1, 4)}

umap_model = UMAP(
    n_neighbors=75,
    n_components=2,
    min_dist=0.1,
    metric='cosine',
    random_state=42)

hdbscan_model = HDBSCAN(min_cluster_size=10,
                        min_samples=None,
                        metric="euclidean",
                        cluster_selection_method="eom",
                        prediction_data=False)

# Training BERTopic model to find best hyperparameters
topic_model = BERTopic(

  # Sub-models
  vectorizer_model=vectorizer_model,
  umap_model=umap_model,
  # hdbscan_model=hdbscan_model,
  representation_model=representation_model,

  # Hyperparameters
  min_topic_size=75,
  n_gram_range=(1,4),
  verbose=True,
)

# Train model
topics, probs = topic_model.fit_transform(combined, embeddings)
# Out:
# 2024-12-23 10:53:29,795 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-12-23 10:55:11,939 - BERTopic - Dimensionality - Completed ✓
# 2024-12-23 10:55:11,941 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-12-23 10:55:14,356 - BERTopic - Cluster - Completed ✓
# 2024-12-23 10:55:14,367 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 100%|██████████| 31/31 [00:10<00:00,  2.84it/s]
# 2024-12-23 10:55:26,949 - BERTopic - Representation - Completed ✓

# %%
# Group documents by topic
documents = pd.DataFrame({"Document": combined,  # Replace with your text data
                          "ID": range(len(combined)),
                          "Topic": topics})
documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer
vectorizer = topic_model.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Create tokens, dictionary, and corpus
words = vectorizer.get_feature_names_out()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]

# Extract topic words
topic_words = [[word for word, _ in topic_model.get_topic(topic)]
               for topic in range(len(set(topics))-1)]

# Compute coherence
coherence_model = CoherenceModel(topics=topic_words,
                                 texts=tokens,
                                 corpus=corpus,
                                 dictionary=dictionary,
                                 coherence='c_v')
coherence = coherence_model.get_coherence()
print(f"Coherence Score: {coherence}")
# Out:
# Coherence Score: 0.7085571065730416

# %%
# Show topics
topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1  10383                      -1_service_customer_work_team
# 1       0   7153                        0_project_manager_sale_team
# 2       1   3437                        1_care_patient_nurse_health
# 3       2   1878           2_engineer_developer_software_experience
# 4       3   1098          3_maintenance_technician_equipment_repair
# 5       4   1014                       4_store_sale_retail_customer
# 6       5   1004                      5_guest_food_restaurant_hotel
# 7       6    708              6_accounting_accountant_tax_financial
# 8       7    529                 7_healthcare_clinical_science_life
# 9       8    417                8_financial_bank_payroll_specialist
# 10      9    361                   9_analyst_business_data_analysis
# 11     10    343                10_teacher_school_student_education
# 12     11    316                   11_attorney_litigation_law_legal
# 13     12    232              12_warehouse_inventory_shift_shipping
# 14     13    181  13_membership_credit_business_partnerresponsib...
# 15     14    179      14_administrative_assistant_executive_support
# 16     15    175         15_therapist_physical_therapy_occupational
# 17     16    152                   16_certified_nursing_cna_hygiene
# 18     17    140                   17_cogent_ip_bridgestone_network
# 19     18    131                       18_driver_cdl_truck_delivery
# 20     19    128                         19_dollar_nan_store_family
# 21     20    121                20_dental_hygienist_dentist_patient
# 22     21    119              21_property_community_leasing_manager
# 23     22    110  22_availability_representative_fun_scheduleswe...
# 24     23    106                  23_veterinary_animal_pet_hospital
# 25     24     98                      24_behavior_autism_bcba_child
# 26     25     97                   25_financial_analyst_analysis_fp
# 27     26     94                       26_pet_petco_welcome_improve
# 28     27     90                   27_dice_destination_career_stage
# 29     28     85                             28_food_store_fresh_10
# 30     29     83                       29_skf_bearing_regolith_1907
#
#                                        Representation  \
# 0   [service, customer, work, team, job, company, ...
# 1   [project, manager, sale, team, marketing, comp...
# 2   [care, patient, nurse, health, medical, regist...
# 3   [engineer, developer, software, experience, da...
# 4   [maintenance, technician, equipment, repair, o...
# 5   [store, sale, retail, customer, associate, man...
# 6   [guest, food, restaurant, hotel, service, cook...
# 7   [accounting, accountant, tax, financial, contr...
# 8   [healthcare, clinical, science, life, patient,...
# 9   [financial, bank, payroll, specialist, client,...
# 10  [analyst, business, data, analysis, requiremen...
# 11  [teacher, school, student, education, learning...
# 12  [attorney, litigation, law, legal, firm, paral...
# 13  [warehouse, inventory, shift, shipping, associ...
# 14  [membership, credit, business, partnerresponsi...
# 15  [administrative, assistant, executive, support...
# 16  [therapist, physical, therapy, occupational, p...
# 17  [certified, nursing, cna, hygiene, assistant, ...
# 18  [cogent, ip, bridgestone, network, ccoi, ticke...
# 19  [driver, cdl, truck, delivery, class, local, h...
# 20  [dollar, nan, store, family, today, avoid, com...
# 21  [dental, hygienist, dentist, patient, dentistr...
# 22  [property, community, leasing, manager, reside...
# 23  [availability, representative, fun, schedulesw...
# 24  [veterinary, animal, pet, hospital, veterinari...
# 25  [behavior, autism, bcba, child, aba, technicia...
# 26  [financial, analyst, analysis, fp, finance, se...
# 27  [pet, petco, welcome, improve, future, create,...
# 28  [dice, destination, career, stage, tech, exper...
# 29  [food, store, fresh, 10, local, lion, address,...
# 30  [skf, bearing, regolith, 1907, rover, spin, pl...
#
#                                           Llama2  \
# 0           [Customer Service, , , , , , , , , ]
# 1         [Project Management, , , , , , , , , ]
# 2               [Nursing Care, , , , , , , , , ]
# 3       [Software Engineering, , , , , , , , , ]
# 4     [Maintenance Technician, , , , , , , , , ]
# 5          [Retail Experience, , , , , , , , , ]
# 6         [Restaurant Service, , , , , , , , , ]
# 7       [Accounting & Finance, , , , , , , , , ]
# 8       [Healthcare Solutions, , , , , , , , , ]
# 9         [Financial Services, , , , , , , , , ]
# 10        [Business Analytics, , , , , , , , , ]
# 11       [Teaching & Learning, , , , , , , , , ]
# 12            [Legal Practice, , , , , , , , , ]
# 13      [Warehouse Operations, , , , , , , , , ]
# 14     [Business Partnerships, , , , , , , , , ]
# 15         [Office Management, , , , , , , , , ]
# 16          [Physical Therapy, , , , , , , , , ]
# 17         [Nursing Assistant, , , , , , , , , ]
# 18       [Tech Infrastructure, , , , , , , , , ]
# 19              [Truck Driver, , , , , , , , , ]
# 20         [Retail Management, , , , , , , , , ]
# 21           [Dental Practice, , , , , , , , , ]
# 22       [Property Management, , , , , , , , , ]
# 23  [Employment Opportunities, , , , , , , , , ]
# 24                  [Vet Care, , , , , , , , , ]
# 25        [Behavioral Analyst, , , , , , , , , ]
# 26        [Financial Analysis, , , , , , , , , ]
# 27              [Pet Wellness, , , , , , , , , ]
# 28                 [Tech Jobs, , , , , , , , , ]
# 29          [Fresh Food Store, , , , , , , , , ]
# 30              [Skf Bearings, , , , , , , , , ]
#
#                                   Representative_Docs
# 0   [assistant store manager work multiple store r...
# 1   [corporate marketing manager job descriptionco...
# 2   [licensed practical nurse capital nursing reha...
# 3   [software engineer job description job summary...
# 4   [facility maintenance engineer manager positio...
# 5   [assistant store manager jersey garden 224 ove...
# 6   [barista job summary barista fill guest servic...
# 7   [senior construction accountant buda tx senior...
# 8   [scientist cell culture thermo fisher scientif...
# 9   [credit analyst 6 bank journey best helping cu...
# 10  [senior technical analyst looking senior techn...
# 11  [grade social study teacher 28 hour school tea...
# 12  [civil litigation associate attorney contract ...
# 13  [warehouse manager role descriptionthis remote...
# 14  [sale manager position summary sale manager ma...
# 15  [administrative assistant job summary seeking ...
# 16  [licensed therapist therapy assistant pt ot pt...
# 17  [certified nursing assistant cna warren hill r...
# 18  [sale company cogent communication global tier...
# 19  [truck driver cdl class penske logistics immed...
# 20  [assistant store manager store family dollar g...
# 21  [office manager aspen dental put first offerin...
# 22  [leasing professional green tree place west ho...
# 23  [customer service representative full part tim...
# 24  [veterinarian mission animal hospital veterina...
# 25  [registered behavior technician looking enthus...
# 26  [senior financial analyst hybrid looking fill ...
# 27  [sale associate create healthier brighter futu...
# 28  [product manager dice leading career destinati...
# 29  [pt center store associate address main street...
# 30  [maintenance technician location ladson sc skf...

# %%
# Add the 'Topic' column to your dataset if it's not already there
dataset['Topic'] = topics

# Create a mapping of Topic -> Llama2 labels
topic_info = topic_model.get_topic_info()
topic_labels = topic_info[['Topic', 'Llama2']].set_index('Topic').to_dict()['Llama2']

# Flatten the labels to ensure single string labels
flattened_labels = {
    topic: (labels[0] if isinstance(labels, list) and len(labels) > 0 else "Unlabeled")
    for topic, labels in topic_labels.items()
}

# Map the flattened labels to the 'Llama2' column in your dataset
dataset['Llama2'] = dataset['Topic'].map(flattened_labels)

# Calculate the percentage each topic represents
total_job_postings = len(dataset)
topic_counts = dataset['Topic'].value_counts()
topic_percentage = (topic_counts / total_job_postings) * 100

# Map the percentage to each row based on its topic
dataset['Topic_Percentage'] = dataset['Topic'].map(topic_percentage.round(2))

# Visualize columns
visualise_columns = ["title", "description", "Topic", "Llama2", "Topic_Percentage"]
dataset = dataset[visualise_columns]

dataset.head(30)
# Out:
#                                                 title  \
# 0                               Marketing Coordinator
# 1                   Mental Health Therapist/Counselor
# 2                         Assitant Restaurant Manager
# 3   Senior Elder Law / Trusts and Estates Associat...
# 4                                  Service Technician
# 5            Economic Development and Planning Intern
# 6                                            Producer
# 7                                   Building Engineer
# 8                               Respiratory Therapist
# 9                                      Worship Leader
# 10                  Inside Customer Service Associate
# 11                                  Project Architect
# 12      Appalachian Highlands Women's Business Center
# 13                                Structural Engineer
# 14                   Senior Product Marketing Manager
# 15                           Osteogenic Loading Coach
# 16                         Administrative Coordinator
# 17                  Customer Service / Reservationist
# 18                     Content Writer, Communications
# 19                                         Controller
# 20                                Physician Assistant
# 21                             Licensed Acupuncturist
# 22                                  Software Engineer
# 23                             Sheet Metal Fabricator
# 24                           Personal Injury Attorney
# 25                   NPE 2024 Exhibition Event Worker
# 26                                  Software Engineer
# 27                                   Loan Coordinator
# 28                                    General Laborer
# 29                                    Swim Instructor
#
#                                           description  Topic  \
# 0   Job descriptionA leading real estate firm in N...     -1
# 1   At Aspen Therapy and Wellness , we are committ...      4
# 2   The National Exemplar is accepting application...    118
# 3   Senior Associate Attorney - Elder Law / Trusts...      5
# 4   Looking for HVAC service tech with experience ...    184
# 5   Job summary:The Economic Development & Plannin...     -1
# 6   Company DescriptionRaw Cereal is a creative de...     -1
# 7   Summary: Due to the pending retirement of our ...     15
# 8   At Children’s, the region’s only full-service ...     -1
# 9   It is an exciting time to be a part of our chu...     -1
# 10  Glastender Inc. is a family-owned manufacturer...     -1
# 11  PGAV Destinations is seeking a self-motivated ...     -1
# 12  FULL JOB DESCRIPTION – PROGRAM DIRECTOR Appala...     -1
# 13  Universal Structural Engineers is seeking a st...     15
# 14  A leading pharmaceutical company committed to ...     -1
# 15  Company DescriptionOsteoStrong® is not a gym, ...     -1
# 16  Job Title: Administrative CoordinatorOrganizat...     -1
# 17  Sentinel Limousine of East Providence RI is a ...     85
# 18  Application opening date: April 24, 2024 Title...     -1
# 19  WORK @ SWShannon Waltchack (SW) is seeking a C...     -1
# 20  We are seeking a qualified Physician Assistant...      8
# 21  Why Work Here?“We’re a growing holistic health...     -1
# 22  Education Bachelor's degree in software, math,...     66
# 23  Sheet metal fabricator for in house shopWeldin...     12
# 24  About Us: We are a small, friendly personal in...      5
# 25  NPE 2024 Exhibition Event Worker﻿Date: 2024/05...     -1
# 26  Job Description:GOYT is seeking a skilled and ...     22
# 27  Morlen Capital Advisors, a boutique commercial...     79
# 28  Looking for a General Laborer for our real est...    113
# 29  HCC is looking to hire professional and experi...     -1
#
#                                              Llama2  Topic_Percentage
# 0   Job Opportunities in Technology and Engineering             50.07
# 1                       Mental Health Professionals              0.94
# 2                             Restaurant Management              0.13
# 3                                Legal Job Openings              0.86
# 4                           HVAC Service Technician              0.08
# 5   Job Opportunities in Technology and Engineering             50.07
# 6   Job Opportunities in Technology and Engineering             50.07
# 7                        Engineering & Construction              0.58
# 8   Job Opportunities in Technology and Engineering             50.07
# 9   Job Opportunities in Technology and Engineering             50.07
# 10  Job Opportunities in Technology and Engineering             50.07
# 11  Job Opportunities in Technology and Engineering             50.07
# 12  Job Opportunities in Technology and Engineering             50.07
# 13                       Engineering & Construction              0.58
# 14  Job Opportunities in Technology and Engineering             50.07
# 15  Job Opportunities in Technology and Engineering             50.07
# 16  Job Opportunities in Technology and Engineering             50.07
# 17                  Customer Service Representative              0.18
# 18  Job Opportunities in Technology and Engineering             50.07
# 19  Job Opportunities in Technology and Engineering             50.07
# 20                              Healthcare Services              0.72
# 21  Job Opportunities in Technology and Engineering             50.07
# 22                        Software Engineering Jobs              0.23
# 23                Industrial Maintenance Technician              0.63
# 24                               Legal Job Openings              0.86
# 25  Job Opportunities in Technology and Engineering             50.07
# 26                                 Java Development              0.49
# 27                          USAA Financial Security              0.19
# 28                         Manufacturing Operations              0.13
# 29  Job Opportunities in Technology and Engineering             50.07

# %%
topic_model.get_topic(11, full=True)["Llama2"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-8dea6dba4a99> in <cell line: 1>()
# ----> 1 topic_model.get_topic(11, full=True)["Llama2"]
#
# TypeError: 'bool' object is not subscriptable

# %%
# Reduce embeddings to 2D
reduced_embeddings = umap_model.fit_transform(embeddings)
print(reduced_embeddings.shape)  # Should return (num_samples, 2)
# Out:
# (30962, 2)

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fc53cf56-a52e-49eb-970e-efb6039fa68a" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc53cf56-a52e-49eb-970e-efb6039fa68a")) {                    Plotly.newPlot(                        "fc53cf56-a52e-49eb-970e-efb6039fa68a",                        [{"customdata":[[0,"project | manager | sale | team | marketing",7153],[1,"care | patient | nurse | health | medical",3437],[2,"engineer | developer | software | experience | data",1878],[3,"maintenance | technician | equipment | repair | operator",1098],[4,"store | sale | retail | customer | associate",1014],[5,"guest | food | restaurant | hotel | service",1004],[6,"accounting | accountant | tax | financial | controller",708],[7,"healthcare | clinical | science | life | patient",529],[8,"financial | bank | payroll | specialist | client",417],[9,"analyst | business | data | analysis | requirement",361],[10,"teacher | school | student | education | learning",343],[11,"attorney | litigation | law | legal | firm",316],[12,"warehouse | inventory | shift | shipping | associate",232],[13,"membership | credit | business | partnerresponsibilities | signpersonally",181],[14,"administrative | assistant | executive | support | office",179],[15,"therapist | physical | therapy | occupational | patient",175],[16,"certified | nursing | cna | hygiene | assistant",152],[17,"cogent | ip | bridgestone | network | ccoi",140],[18,"driver | cdl | truck | delivery | class",131],[19,"dollar | nan | store | family | today",128],[20,"dental | hygienist | dentist | patient | dentistry",121],[21,"property | community | leasing | manager | resident",119],[22,"availability | representative | fun | schedulesweekly | employerfast",110],[23,"veterinary | animal | pet | hospital | veterinarian",106],[24,"behavior | autism | bcba | child | aba",98],[25,"financial | analyst | analysis | fp | finance",97],[26,"pet | petco | welcome | improve | future",94],[27,"dice | destination | career | stage | tech",90],[28,"food | store | fresh | 10 | local",85],[29,"skf | bearing | regolith | 1907 | rover",83]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[7153,3437,1878,1098,1014,1004,708,529,417,361,343,316,232,181,179,175,152,140,131,128,121,119,110,106,98,97,94,90,85,83],"sizemode":"area","sizeref":4.470625,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[15.599958,9.563854,15.680913,20.944641,13.7963915,13.589798,16.10974,15.260376,16.192553,0.6906884,13.229495,16.412657,21.042477,15.690397,13.429243,9.733089,9.949872,15.25087,21.19855,13.258498,9.735575,14.099398,0.97717327,9.076509,13.106405,0.81069714,8.965301,15.7275,1.040883,15.632615],"xaxis":"x","y":[5.6291595,2.411464,5.0257373,26.18447,4.9091907,3.876718,7.158673,5.4542956,7.202482,11.718276,3.3015015,7.4482284,26.086603,5.7504983,4.25262,2.7191398,2.1834338,5.9534154,25.930553,3.8867831,1.9591149,4.599216,-7.847749,2.5689785,3.2219453,11.598236,2.715658,4.8643656,-7.7839437,6.0925217],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,3 ...

# %%
plot = topic_model.visualize_documents(combined, embeddings=embeddings)
plot

# %%
# Extract Llama2 labels from topic info
topic_info = topic_model.get_topic_info()
llama2_labels = topic_info['Llama2'].tolist()

# Assign labels to each document based on topics
document_topics = topic_model.get_document_info(combined)['Topic']
labels = [llama2_labels[topic] if topic != -1 else "Unlabeled" for topic in document_topics]

flattened_labels = [
    label[0] if isinstance(label, list) and len(label) > 0 else "Unlabeled"
    for label in labels
]

print(flattened_labels[:10])  # Inspect the first few labels
# Out:
# ['Customer Service', 'Unlabeled', 'Retail Experience', 'Unlabeled', 'Unlabeled', 'Unlabeled', 'Project Management', 'Unlabeled', 'Nursing Care', 'Customer Service']

# %%
datamapplot.create_plot(
    data_map_coords=embeddings,
    labels=flattened_labels,
    title="Visualization of Job Postings with Llama2 Labels",
    sub_title="Generated using BERTopic and datamapplot",
    label_font_size=11,
    label_wrap_width=20,
    use_medoids=True,
)
